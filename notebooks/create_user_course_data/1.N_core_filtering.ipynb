# %% [markdown]
# <h1>0. Import library 🥱</h1>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import random

# %% [markdown]
# <h1>1. Create n_core_filter class 🥴</h1>

# %%
class n_core_filter:
    def __init__(self, user_path, n_core): # Constructor
        self.user_path = user_path
        self.n_core = n_core

    def load_data(self): # Load dữ liệu
        df = pd.read_csv(self.user_path,
                         encoding = 'utf-8')

        self.df = df.reset_index(drop = True)

    def sampling_user(self, nums):
        sampling_user = self.df['user'].unique().tolist()
        np.random.shuffle(sampling_user)
        sampling_user = sampling_user[:nums]
        self.df = self.df[self.df['user'].isin(sampling_user)]

    def filtering(self):
        pre_len = -1 # Biến lưu trữ độ dài trước khi lọc n_core của df, được khởi tạo -1 để bắt đầu vòng lặp

        while pre_len != self.df.shape[0]: # Khi pre_len trùng với độ dài df (tức là không còn user, course có thể lọc) kết thúc vòng lặp:
            pre_len = self.df.shape[0]  # Lưu độ dài trước khi lọc

            self.df = self.df.groupby('user').filter(lambda x: len(x) >= self.n_core) # Lọc user có số course >= n_core
            self.df = self.df.groupby('course').filter(lambda x: len(x) >= self.n_core) # Lọc course có số user >= n_core

    def get_df(self):
        return self.df

    def to_csv(self, path):
        self.df.to_csv(path, index = False)

# %% [markdown]
# <h1>2. Using class 😳</h1>

# %%
data_path = '/content/drive/MyDrive/Nhom12/ĐAMH/Project/Data/transformed_data/user_course.csv'

df = n_core_filter(data_path, 5)
df.load_data()
df.filtering()

to_see = df.get_df()
to_see.head()
# Out:
#    user    course          enroll_time
# 1  U_24  C_597314  2019-06-12 17:22:07
# 2  U_24  C_597208  2019-06-17 15:22:41
# 3  U_24  C_682129  2019-10-06 16:23:51
# 4  U_24  C_674910  2019-10-08 17:51:04
# 5  U_24  C_707038  2019-10-13 13:06:25

# %%
to_see.shape
# Out:
# (7446536, 3)

# %%
to_see['user'].unique().shape
# Out:
# (370846,)

# %%
to_see['course'].unique().shape
# Out:
# (3067,)

# %%
df.sampling_user(100000)
df.filtering()

to_see = df.get_df()
to_see.head()
# Out:
#    user    course          enroll_time
# 1  U_24  C_597314  2019-06-12 17:22:07
# 2  U_24  C_597208  2019-06-17 15:22:41
# 3  U_24  C_682129  2019-10-06 16:23:51
# 4  U_24  C_674910  2019-10-08 17:51:04
# 5  U_24  C_707038  2019-10-13 13:06:25

# %%
to_see['user'].unique().shape
# Out:
# (99966,)

# %%
to_see['course'].unique().shape
# Out:
# (2808,)

# %%
df.to_csv('/content/drive/MyDrive/Nhom12/ĐAMH/Project/Data/transformed_data/n_core_user_course.csv')

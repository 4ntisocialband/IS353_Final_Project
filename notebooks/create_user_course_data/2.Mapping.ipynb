# %% [markdown]
# <h1>0. Import library 🥱</h1>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import csv

# %% [markdown]
# <h1>1. Create Mapping class 🥴</h1>

# %%
class mapping:
    def __init__(self, data_path): # Constructor
        self.data_path = data_path

    def load_data(self): # Data loader
        self.df = pd.read_csv(self.data_path)

    def mapping(self, col):
        map = {}

        int_col = pd.DataFrame(self.df[col].unique()).rename(columns = {0: col}) # Lấy các giá trị unique của cột

        int_col[col] = int_col[col].apply(lambda x: x.strip(' ')) # Format cột (cho chắc chắn)

        for i in range(len(int_col[col])):
            map[int_col[col][i]] = i # Tạo mapping

        print(map)

        return map

    def create_mapping(self):
        self.course_map = self.mapping('course') # Tạp map cho cột course
        self.user_map = self.mapping('user') # Tạp map cho cột user

    def apply_mapping(self):
        self.df['course'] = self.df['course'].apply(lambda x: self.course_map[x]) # Chuyển đổi cột user
        self.df['user'] = self.df['user'].apply(lambda x: self.user_map[x]) # Chuyển đổi cột course

    def map_to_csv(self, user_path, course_path):
        with open(user_path, 'w') as csv_file: # Ghi user map vào đường dẫn user_path
            writer = csv.writer(csv_file)

            for key, value in self.user_map.items():
                writer.writerow([key, value])

            csv_file.close()

        with open(course_path, 'w') as csv_file: # Ghi course map vào đường dẫn course_path
            writer = csv.writer(csv_file)

            for key, value in self.course_map.items():
                writer.writerow([key, value])

            csv_file.close()

    def data_to_csv(self, data_path):
        self.df.to_csv(data_path, index = False) # Lưu dữ liệu

# %% [markdown]
# <h1>2. Using class 😳</h1>

# %%
data_path = '/content/drive/MyDrive/Nhom12/ĐAMH/Project/Data/transformed_data/n_core_user_course.csv'
user_map = '/content/drive/MyDrive/Nhom12/ĐAMH/Project/Data/transformed_data/map/user_map.csv'
course_map = '/content/drive/MyDrive/Nhom12/ĐAMH/Project/Data/transformed_data/map/course_map.csv'

map_writer = mapping(data_path)
map_writer.load_data()
map_writer.create_mapping()
map_writer.apply_mapping()
map_writer.map_to_csv(user_map, course_map)
map_writer.data_to_csv('/content/drive/MyDrive/Nhom12/ĐAMH/Project/Data/transformed_data/mapped/mapped_n_core_user_course.csv')
# Out:
# Output hidden; open in https://colab.research.google.com to view.
